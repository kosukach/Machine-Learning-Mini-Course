Northern Mariana Islands	11	18	2	0
Central African Republic	11	8	0	3
Falkland Islands	11	10	0	1
Sierra Leone	11	11	0	0
Montserrat	11	10	0	1
Greenland	11	0	0	11
Cape Verde	11	10	1	0
Nicaragua	11	6	1	4
Seychelles	11	11	0	0
Akrotiri	10	10	0	0
Åland Islands	10	10	0	0
Suriname	10	3	1	6
Gambia	9	6	1	2
Luhansk PR	8	7	0	1
Vatican City	8	6	0	2
Mauritania	7	4	1	2
Saint Barthélemy	6	5	0	1
East Timor	6	5	0	1
Artsakh	5	5	0	0
Burundi	5	4	1	0
Bhutan	5	3	0	2
São Tomé	4	4	0	0
South Sudan	4	4	0	0
British Virgin Islands	3	3	0	0
Anguilla	3	3	0	0
Saba	2	2	0	0
Sint Eustatius	2	2	0	0
Somaliland	2	2	0	0
Papua New Guinea	2	2	0	0
Yemen	1	1	0	0
Abkhazia	1	1	0	0
Guantanamo Bay	1	1	0	0"""

# %%
cor = cor.replace("	", " ")
cor = cor.split("\n")
cor
# Out:
# ['United States 612380 538395 25949 48036',
#  'Spain 174060 88301 18255 67504',
#  'Italy 162488 104291 21067 37130',
#  'Germany 132210 70603 3495 58112',
#  'France 103573 59039 15729 28805',
#  'United Kingdom 93873 81558 12107 208',
#  'China 82052 1138 3339 77575',
#  'Iran 74877 22065 4683 48129',
#  'Turkey 65111 58909 1403 4799',
#  'Belgium 31119 20094 4157 6868',
#  'Netherlands 27419 24474 2945 0',
#  'Canada 27063 17925 903 8235',
#  'Switzerland 25936 10062 1174 14700',
#  'Brazil 25262 9704 1532 14026',
#  'Russia 21102 19238 170 1694',
#  'Portugal 17448 16534 567 347',
#  'Austria 14234 6217 384 7633',
#  'Georgia 14223 13950 501 69',
#  'Israel 12046 9728 123 2195',
#  'Ireland 11479 11048 406 25',
#  'Sweden 11445 10039 1033 373',
#  'India 10815 9272 353 1190',
#  'South Korea 10591 2750 225 7616',
#  'Peru 10303 7204 230 2869',
#  'Chile 7917 5179 92 2646',
#  'Japan 7645 6683 109 853',
#  'Ecuador 7603 6552 355 696',
#  'Poland 7202 6321 263 618',
# ...

# %%
cor = list(map(lambda x: x.split(" "), cor))

# %%
cor
# Out:
# [['United', 'States', '612380', '538395', '25949', '48036'],
#  ['Spain', '174060', '88301', '18255', '67504'],
#  ['Italy', '162488', '104291', '21067', '37130'],
#  ['Germany', '132210', '70603', '3495', '58112'],
#  ['France', '103573', '59039', '15729', '28805'],
#  ['United', 'Kingdom', '93873', '81558', '12107', '208'],
#  ['China', '82052', '1138', '3339', '77575'],
#  ['Iran', '74877', '22065', '4683', '48129'],
#  ['Turkey', '65111', '58909', '1403', '4799'],
#  ['Belgium', '31119', '20094', '4157', '6868'],
#  ['Netherlands', '27419', '24474', '2945', '0'],
#  ['Canada', '27063', '17925', '903', '8235'],
#  ['Switzerland', '25936', '10062', '1174', '14700'],
#  ['Brazil', '25262', '9704', '1532', '14026'],
#  ['Russia', '21102', '19238', '170', '1694'],
#  ['Portugal', '17448', '16534', '567', '347'],
#  ['Austria', '14234', '6217', '384', '7633'],
#  ['Georgia', '14223', '13950', '501', '69'],
#  ['Israel', '12046', '9728', '123', '2195'],
# ...

# %%
cor = np.array(list(map(lambda x: np.append(np.array(list(map(lambda y: int(y), x[-4:]))), (" ".join(x[:-4]))), cor)))
cor
# Out:
# array([['612380', '538395', '25949', '48036', 'United States'],
#        ['174060', '88301', '18255', '67504', 'Spain'],
#        ['162488', '104291', '21067', '37130', 'Italy'],
#        ...,
#        ['1', '1', '0', '0', 'Yemen'],
#        ['1', '1', '0', '0', 'Abkhazia'],
#        ['1', '1', '0', '0', 'Guantanamo Bay']], dtype='<U24')

# %%
cor.shape
# Out:
# (220, 5)

# %%
df = pd.DataFrame(cor, index=cor[0:, 4])

# %%
df = df.sort_values(by=[4])

# %%
df.drop(4, axis=1, inplace=True)

# %%
df.columns = ["total", "active", "deaths", "recovered"]

# %%
df
# Out:
#               total active deaths recovered
# Abkhazia          1      1      0         0
# Afghanistan     714    651     23        40
# Akrotiri         10     10      0         0
# Albania         475    203     24       248
# Algeria        2070   1053    326       691
# ...             ...    ...    ...       ...
# Vietnam         266     97      0       169
# Yemen             1      1      0         0
# Zambia           45     13      2        30
# Zimbabwe         17     14      3         0
# Åland Islands    10     10      0         0
#
# [220 rows x 4 columns]

# %%
mort = pd.read_csv("./Datasets/mortality rate.csv", sep=";", index_col=0)
pop = pd.read_csv("./Datasets/pop.csv", sep=";", index_col=0)
med = pd.read_csv("./Datasets/med_age.csv", sep=";", index_col=0)#insufficient
#CREATE DF WITH ALL UN DATA AND THEN CONCAT

# %%
ind = list(map(lambda x: x in mort.index, df.index))
ind1 = list(map(lambda x: x in df.index, mort.index))

# %%
df.loc[ind].index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla',
#        'Argentina', 'Armenia', 'Aruba', 'Australia',
#        ...
#        'Turkey', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'Uruguay', 'Uzbekistan', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=172)

# %%
df.loc[ind].index == mort.loc[ind1].index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
main_fraim = pd.concat([df.loc[ind], mort.loc[ind1], pop.loc[ind1]], axis=1)

# %%
main_fraim
# Out:
#             total active deaths recovered mortality_rate       pop
# Afghanistan   714    651     23        40         38 928    38 928
# Albania       475    203     24       248          2 878     2 878
# Algeria      2070   1053    326       691         43 851    43 851
# Andorra       659    468     31       160             77        77
# Angola         19     15      2         2         32 866    32 866
# ...           ...    ...    ...       ...            ...       ...
# Uruguay       492    224      8       260          3 474     3 474
# Uzbekistan   1165   1062      4        99         33 469    33 469
# Yemen           1      1      0         0         29 826    29 826
# Zambia         45     13      2        30         18 384    18 384
# Zimbabwe       17     14      3         0         14 863    14 863
#
# [172 rows x 6 columns]
